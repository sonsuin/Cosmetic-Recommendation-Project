# %%
# !pip install cx_Oracle

# %%
import cx_Oracle
conn = cx_Oracle.connect("scott/tiger@localhost:1521/xe")
cursor = conn.cursor()

import re
customerList = dict()
from time import sleep

# %% [markdown]
# - __init__(): 생성자 메서드
# - main_menu_list(): 메인 메뉴 리스트, 단순 출력
# - main_menu(): 메인 메뉴
# - login_signup_menu_list(): 로그인, 회원가입 메뉴 리스트, 단순 출력
# - login_signup_menu(): 로그인 메뉴
# - login_logout(): 로그인 or 로그아웃 상태 체크 메서드
#
# - do_login(): 로그인 하는 메서드
# - do_logout(): 로그아웃 하는 메서드
# - set_id(): 회원가입시 id 입력 메서드
# - check_id(): id의 유효성을 검사하는 메서드
# - set_pwd(): 회원가입시 비밀번호를 입력하는 메서드
# - check_pwd(): pwd의 유효성을 검사하는 메서드
# - set_name(): 회원가입시 이름을 입하고 유효성을 검사하는 메서드
# - set_tel(): 회원가입시 전화번호를 입력하고 유효성을 검사하는 메서드
# - save_mem(): 회원가입 정보를 저장하는 메서드
# - show_info(): 회원가입 정보가 출력되는 메서드
# - disp_info(): 로그인 정보가 출력되는 메서드(로그인x시 공란)
#
# - choose_gender(): 스킨케어 서비스 설문의 성별을 선택하는 메서드, 나이, 피부타입을 선택하고 돌아와서 설문 정보를 저장한다.
# - choose_age():  나이를 선택하는 메서드
# - choose_skin(): 피부타입을 선택하는 메서드
# - survey_summary(): 설문 결과를 보러갈지 선택하는 메서드
# - result(): 설문 결과를 출력하는 메서드
# - skin_typeall(): 피부 타입에 따른 모든 화장품을 출력하는 메서드
# - old_all(): 나이에 따른 모든 화장품을 출력하는 메서드
# - cosmetic_all: 모든 화장품을 출력하는 메서드
# - myresult: 이전 설문 결과를 출력하는 메서드, 없으면 출력되지 않고 메인 메뉴로 돌아간다.

# %%
# 전체 완성 코드

class Cosmetic:

    # 생성자 메서드
    def __init__(self, _id='', pwd='', name='', gender='', tel='', old='', skin=''):
        self._id = _id
        self.pwd = pwd
        self.name = name
        self.tel = tel
        self.gender = gender
        self.old = old
        self.skin = skin
        self.login = False # 로그인 제어
        self.control = True # 로그인 메뉴에서 종료하기 위해서(메인메뉴의 while을 끄는 용도)
        self.control2 = True # 비밀번호 화면에서 로그인을 취소하기 위해서(없으면 id입력창이 다시 뜬다)


        
        
    # 메인 메뉴 리스트
    def main_menu_list(self):
        print("\n","➖"*9,"S K I N C A R E  S E R V I C E","➖"*9)
        print("1. 스킨케어 추천 서비스")
        print("2. 연령별 화장품 리스트 보기")
        print("3. 피부타입별 화장품 리스트 보기")
        print("4. 모든 화장품 리스트 보기")
        print("5. 이전 결과 리스트 보기")
        if self.login == False:
            print("6. 로그인, 회원가입 메뉴")
        else:
            print("6. 로그아웃")
        print("7. 종료")
        print("➖"*30,"\n")
        self.disp_info() # 현재 로그인 정보 출력
                
        
    # 메인 메뉴 
    def main_menu(self):
        self.main_menu_list() # 메인 메뉴 리스트 단순 출력
        while self.control: # 중첩 반복문 탈출하기 위해 사용
            menu2_num = input("번호를 입력해 주세요 ▶ ")
            if self.login == False:  # 로그인x일 경우 동작
                if menu2_num == '1':
                    print("서비스를 이용하기 위해서는 로그인이 필요합니다.")
                elif menu2_num == '2':
                    print("서비스를 이용하기 위해서는 로그인이 필요합니다.")
                elif menu2_num == '3':
                    print("서비스를 이용하기 위해서는 로그인이 필요합니다.")
                elif menu2_num == '4':
                    print("서비스를 이용하기 위해서는 로그인이 필요합니다.")
                elif menu2_num == '5':
                    print("서비스를 이용하기 위해서는 로그인이 필요합니다.")
                elif menu2_num == '6':
                    self.login_signup_menu() # 로그인 회원가입 메뉴 호출
                elif menu2_num == '7':
                    print("프로그램을 종료합니다.")
                    break
                else:
                    print("잘못 입력하셨습니다.")

            elif self.login == True: # 로그인o일 경우 동작
                if menu2_num == '1':
                    self.choose_gender() # 설문-성별 선택 메서드 호출
                    self.main_menu_list()
                elif menu2_num == '2':
                    self.old_all() # 나이별 화장품 목록을 출력 메서드 호출
                    self.main_menu_list()
                elif menu2_num == '3':
                    self.skin_typeall() # 피부타입별 화장품 목록을 출력 메서드 호출
                    self.main_menu_list()
                elif menu2_num == '4':
                    self.cosmetic_all() # 모든 화장품 목록을 출력 메서드 호출
                    self.main_menu_list()
                elif menu2_num == '5':
                    self.myresult() # 이전 설문 결과를 출력 메서드 호출
                    self.main_menu_list()
                elif menu2_num == '6':
                    self.do_logout() # 로그아웃 메서드 호출
                    self.main_menu_list()
                    print("로그아웃 되었습니다.")
                elif menu2_num == '7':
                    print("프로그램을 종료합니다.")
                    break
                else:
                    print("잘못 입력하셨습니다.")
                    
 

            
    def login_signup_menu_list(self):
        print("\n","➖"*13,"J O I N","➖"*13)
        if self.login == False: # 로그인 상태에 따라 출력 메세지가 달라진다.
            print("1. 로그인")
        else:
            print("1. 로그아웃")
        print("2. 회원가입")
        print("3. 메인 메뉴")
        print("4. 프로그램 종료")
        print("➖"*30,"\n")
        self.disp_info() # 현재 로그인 정보 출력
                    
        
    # 로그인, 회원가입 메서드      
    def login_signup_menu(self):
        self.login_signup_menu_list() # 로그인, 회원가입 리스트 단순 출력
        while True:
            menu1 = input("번호를 선택해 주세요 ▶ ")
            if menu1 == '1':
                self.login_logout() # 로그인 상태에 따라 로그인 혹은 로그아웃 
                self.login_signup_menu_list() # 단순 출력
            elif menu1 == '2':
                if self.login == False:
                    print("회원가입합니다")
                    self.set_id() # 회원가입: 아이디 > 비밀번호 > 이름 > 전화번호를 입력한다.
                    self.set_pwd()
                    self.set_name()
                    self.set_tel()
                    self.save_mem() # 회원가입 정보를 저장한다.
                    self.login = True # 회원가입 완료시 자동 로그인 되도록
                    self.login_signup_menu_list() # 단순 출력
                else:
                    print("로그인 중입니다.")
            elif menu1 == '3':
                print("메인 메뉴로 이동합니다")
                self.main_menu_list() # 단순 출력
                break
            elif menu1 == '4':
                print("프로그램을 종료합니다.", end="")
                self.control = False # 메인 메뉴의 while의 동작 종료
                break
            else:
                print("잘못 입력하셨습니다.")

                
                
                

    def login_logout(self): # 로그인, 로그아웃 함수
        if self.login == False:
            print("로그인 합니다.")
            self.do_login() # 로그인 메서드
        else:
            print("로그아웃 합니다.")
            self.do_logout() #로그아웃 메서드
            self.login_signup_menu_list() # 단순 출력

    def do_login(self): # 로그인 함수
        self.control2 = True # 로그인 함수가 처음 호출 되었을 때 while문을 동작 하도록
        while self.control2:
            uid = input('아이디를 입력해 주세요 ▶ ')
            if uid in customerList.keys(): # 회원 정보에 입력 받은 id가 있으면 동작
                i =1
                for i in range(1, 4):
                    pwd = input('비밀번호 ▶ ')
                    if customerList.get(uid)[0] == pwd: # 비밀번호가 일치하면 동작
                        self._id = uid
                        self.pwd = customerList.get(uid)[0]
                        self.name = customerList.get(uid)[1]
                        self.tel = customerList.get(uid)[2]
                        self.gender = customerList.get(uid)[3]
                        self.old = customerList.get(uid)[4]
                        self.skin = customerList.get(uid)[5]
                        self.login = True
                        print("로그인 되셨습니다.")
                        break
                    elif pwd == "종료": # 종료를 입력 받으면 동작, 로그인 함수의 while문을 중지 시킴
                        print("메뉴로 돌아갑니다.")
                        self.control2 = False
                        break
                    else: # 비밀번호 잘못 입력시 횟수 출력
                        print("비밀번호를 %d회 잘못 입력 하였습니다." % i)
                if i == 3: # 3회 비밀번호 잘못 입력시 동작
                    print("")
                    print("부정한 접속 시도가 감지되었습니다.")
                    print("5초간 시스템 사용이 불가능 합니다.")
                    sleep(5)
                    print("이제 시스템 사용이 가능합니다.")
                    break
                break    
            elif uid == '종료':
                print("메뉴로 돌아갑니다.")
                break
            else:
                print("ID가 존재하지 않습니다.")
                print("메뉴로 돌아가시려면 '종료'를 입력해 주세요")

    def do_logout(self): # 로그아웃 함수
        self._id = ""
        self.pwd = ''
        self.name = ''
        self.tel = ''
        self.gender = ''
        self.old = ''
        self.skin = ''
        self.login = False                


        
        

                    
    def set_id(self): # 아이디 입력 함수
        while True:
            self._id = input("아이디를 입력해 주세요 ▶ ")
            if self.check_id() == True: # id 유효성 검사하고 나오는 함수
                break


    def check_id(self): # 아이디 유효성 검사
        if self._id not in customerList:
            if len(re.findall("[a-z]+", self._id)) == 0 or len(re.findall("[A-Z]", self._id)) != 0 or len(
                    re.findall("[0-9]", self._id)) == 0:
                print("규격에 맞지않습니다.")
                print("영어소문자와 숫자로 작성해주십시오.")
                return False
            elif len(self._id) < 6 or len(self._id) > 12:
                print("아이디의 길이는 6자리이상 12자리 이하로 설정해주십시오.")
                return False
            else:
                print("올바른 형식입니다.")
                return True
        else:
            print("이미 존재하는 아이디입니다.")

    def set_pwd(self): # 비밀번호 입력 함수
        while True:
            self.pwd = input("비밀번호를 입력해 주세요 ▶ ")
            if self.pwd_check() == True:
                break
        while True:
            dcheck = input("다시한번 입력해 주세요 ▶ ")
            if self.pwd == dcheck:
                break
            else:
                print("잘못 입력하였습니다.")


    def pwd_check(self): # 비밀번호 유효성 검사

        # 문자의 길이 체크
        if len(self.pwd) < 6 or len(self.pwd) > 12:
            print(self.pwd, "의 길이가 적당하지 않습니다.")
            return False

        # 숫자와 영문자로만 구성되어야 한다.
        elif re.findall("[a-zA-Z0-9]+", self.pwd)[0] != self.pwd:
            print(self.pwd, "숫자와 영문자로만 구성되어야 합니다.")
            return False

        # 영문자는 대문자와 소문자가 포함되어야 한다.
        elif len(re.findall("[a-z]", self.pwd)) == 0 or len(re.findall("[A-Z]", self.pwd)) == 0 or len(
                re.findall("[0-9]", self.pwd)) == 0:
            print(self.pwd, "대문자 또는 소문자가 모두 필요합니다.")
            return False

        print(self.pwd, "올바른 형식의 비밀번호 입니다.")
        return True

    
    def set_name(self): # 이름 입력 및 유효성 검사 함수
        while True:
            n = input("이름 ▶ ")
            if len(re.findall("[a-z]", n)) != 0 or len(re.findall("[A-Z]", n)) != 0 or len(re.findall("[0-9]", n)) != 0 or len(re.findall('[\W]+', n)) != 0 :
                print("규격에 맞지않습니다.")
                print("한글로 작성해주십시오.")
            else:
                print("올바른 형식입니다.")
                self.name = n
                break


    def set_tel(self): # 전화번호 입력 및 유효성 검사 함수
        while True:
            t = input("전화번호 ▶  ")
            print("000-0000-0000 규격으로 입력해주세요.")
            if re.match('[0-9]{3}-[0-9]{4}-[0-9]{4}', t):  # 숫자 3개-4개-4개 패턴
                print("회원등록이 완료되었습니다.")
                self.tel = t
                break
            else:
                print("다시 입력해주세요.")
        self.show_info()

        
    def save_mem(self): # 회원정보를 리스트에 담는 함수
        customerList[self._id] = [self.pwd, self.name, self.tel, self.gender, self.old, self.skin]

    def show_info(self): # 회원가입 완료 후 회원 정보 출력 함수
        print("\n", "귀하의 가입정보는\n 아이디 : {}\n 비밀번호 : {}\n 이름 :{}\n 전화번호 : {}입니다.".format(self._id, self.pwd, self.name,
                                                                                       self.tel))

    def disp_info(self): # 프로그램 실행시 하단에 표시되는 로그인 중인 회원정보(입력하지 않으면 공란이 뜸)
        print("\t\t\t      🔹🔷🔹","접속 정보","🔹🔷🔹")
        print("아이디: {}  비밀번호: {}  이름: {}  전화번호: {}입니다.\n".format(self._id, self.pwd, self.name, self.tel))

        
        
        
        
    def choose_gender(self):  # 성별고르는 함수명
        print("➖" * 11, '스킨케어 추천 서비스', "➖" * 11, '\n')
        while True:
            a = input("🟠 성별을 입력해주세요 1.여자  2.남자 ▶ ")
            if a == '1':
                self.gender = '여자'
                self.choose_age()
                self.choose_skin()
                customerList.get(self._id)[3] = self.gender
                customerList.get(self._id)[4] = self.old
                customerList.get(self._id)[5] = self.skin
                break

            elif a == '2':
                self.gender = '남자'
                self.choose_age()
                self.choose_skin()
                customerList.get(self._id)[3] = self.gender
                customerList.get(self._id)[4] = self.old
                customerList.get(self._id)[5] = self.skin
                break

            else:
                print("다시 입력해주세요")
        self.survey_summary()

    def choose_age(self):  # 나이대를 고르는 함수
        while True:
            b = input("🟡 나이대를 입력해주세요 1.10대  2.20대  3.30대  4.40대+ ▶  ")
            if b == '1':
                self.old = '10대'
                break
            elif b == '2':
                self.old = '20대'
                break
            elif b == '3':
                self.old = '30대'
                break
            elif b == '4':
                self.old = '40대'
                break
            else:
                print("다시 입력해주세요")

    def choose_skin(self):  # 피부타입을 고르는 함수
        while True:
            c = input("🟢 피부타입을 입력해주세요 1.건성  2.지성  3.민감성 ▶ ")
            if c == '1':
                self.skin = '건성'
                break
            elif c == '2':
                self.skin = '지성'
                break
            elif c == '3':
                self.skin = '민감성'
                break
            else:
                print("다시 입력해주세요")

                # 현재 선택한 항목 출력

    def survey_summary(self): # 선택지 내역 출력 및 결과이동 함수
        print("➖" * 30)
        print("\n", self.name + "은 {0}, {1}, {2}를 선택하셨습니다.".format(self.gender, self.old, self.skin))
        while True:
            survey_result = input('결과를 보러 가시겠습니까? 1. Yes  2. No ▶ ')
            if survey_result == '1':
                self.result()
                break
            elif survey_result == '2':
                break
            else:
                print('다시 입력하세요')

    def result(self): # 결과 값 제출 함수 (오라클 연동)
        print("\n", "➖" * 12, "💌 결과 💌", "➖" * 12)
        print()
        if self.gender == '여자' and self.old == '10대' and self.skin == '건성':
            sql1 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%10대%' and type like '%건성%'"
            cursor.execute(sql1)
            for row in cursor:
                print(row)
        elif self.gender == '여자' and self.old == '10대' and self.skin == '지성':
            sql2 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%10대%' and type like '%지성%'"
            cursor.execute(sql2)
            for row in cursor:
                print(row)
        elif self.gender == '여자' and self.old == '10대' and self.skin == '민감성':
            sql3 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%10대%' and type like '%민감성%'"
            cursor.execute(sql3)
            for row in cursor:
                print(row)
        elif self.gender == '여자' and self.old == '20대' and self.skin == '건성':
            sql4 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%20대%' and type like '%건성%'"
            cursor.execute(sql4)
            for row in cursor:
                print(row)
        elif self.gender == '여자' and self.old == '20대' and self.skin == '지성':
            sql5 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%20대%' and type like '%지성%'"
            cursor.execute(sql5)
            for row in cursor:  # 커서가 가리키는 1개의 레코드를 row에 저장
                print(row)
        elif self.gender == '여자' and self.old == '20대' and self.skin == '민감성':
            sql6 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%20대%' and type like '%민감성%'"
            cursor.execute(sql6)
            for row in cursor:  # 커서가 가리키는 1개의 레코드를 row에 저장
                print(row)
        elif self.gender == '여자' and self.old == '30대' and self.skin == '건성':
            sql7 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%30대%' and type like '%건성%'"
            cursor.execute(sql7)
            for row in cursor:  # 커서가 가리키는 1개의 레코드를 row에 저장
                print(row)
        elif self.gender == '여자' and self.old == '30대' and self.skin == '지성':
            sql8 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%30대%' and type like '%지성%'"
            cursor.execute(sql8)
            for row in cursor:  # 커서가 가리키는 1개의 레코드를 row에 저장
                print(row)
        elif self.gender == '여자' and self.old == '30대' and self.skin == '민감성':
            sql9 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%30대%' and type like '%민감성%'"
            cursor.execute(sql9)
            for row in cursor:  # 커서가 가리키는 1개의 레코드를 row에 저장
                print(row)
        elif self.gender == '여자' and self.old == '40대' and self.skin == '건성':
            sql10 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%40대%' and type like '%건성%'"
            cursor.execute(sql10)
            for row in cursor:  # 커서가 가리키는 1개의 레코드를 row에 저장
                print(row)
        elif self.gender == '여자' and self.old == '40대' and self.skin == '지성':
            sql11 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%40대%' and type like '%지성%'"
            cursor.execute(sql11)
            for row in cursor:  # 커서가 가리키는 1개의 레코드를 row에 저장
                print(row)
        elif self.gender == '여자' and self.old == '40대' and self.skin == '민감성':
            sql12 = "select name, price, company from cosmetic_product where gender like '%여자%' and age like '%40대%' and type like '%민감성%'"
            cursor.execute(sql12)
            for row in cursor:  # 커서가 가리키는 1개의 레코드를 row에 저장
                print(row)

        elif self.gender == '남자' and self.old == '10대' and self.skin == '건성':
            sql13 = "select name, price, company from cosmetic_product where gender like '%self.gender%' and age like '%self.old%' and type like '%self.skin%'"
            cursor.execute(sql13)
            for row in cursor:
                print(row)
        elif self.gender == '남자' and self.old == '10대' and self.skin == '지성':
            sql14 = "select name, price, company from cosmetic_product where gender like '%남자%' and age like '%10대%' and type like '%지성%'"
            cursor.execute(sql14)
            for row in cursor:
                print(row)
        elif self.gender == '남자' and self.old == '10대' and self.skin == '민감성':
            sql15 = "select name, price, company from cosmetic_product where gender like '%남자%' and age like '%10대%' and type like '%민감성%'"
            cursor.execute(sql15)
            for row in cursor:
                print(row)
        elif self.gender == '남자' and self.old == '20대' and self.skin == '건성':
            sql16 = "select name, price, company from cosmetic_product where gender like '%남자%' and age like '%20대%' and type like '%건성%'"
            cursor.execute(sql16)
            for row in cursor:
                print(row)
        elif self.gender == '남자' and self.old == '20대' and self.skin == '지성':
            sql17 = "select name, price, company from cosmetic_product where gender like '%남자%' and age like '%20대%' and type like '%지성%'"
            cursor.execute(sql17)
            for row in cursor:
                print(row)
        elif self.gender == '남자' and self.old == '20대' and self.skin == '민감성':
            sql18 = "select name, price, company from cosmetic_product where gender like '%남자%' and age like '%20대%' and type like '%민감성%'"
            cursor.execute(sql18)
            for row in cursor:
                print(row)
        elif self.gender == '남자' and self.old == '30대' and self.skin == '건성':
            sql19 = "select name, price, company from cosmetic_product where gender like '%남자%' and age like '%30대%' and type like '%건성%'"
            cursor.execute(sql19)
            for row in cursor:
                print(row)
        elif self.gender == '남자' and self.old == '30대' and self.skin == '지성':
            sql20 = "select name, price, company from cosmetic_product where gender like '%남자%' and age like '%30대%' and type like '%지성%'"
            cursor.execute(sql20)
            for row in cursor:
                print(row)
        elif self.gender == '남자' and self.old == '30대' and self.skin == '민감성':
            sql21 = "select name, price, company from cosmetic_product where gender like '%남자%' and age like '%30대%' and type like '%민감성%'"
            cursor.execute(sql21)
            for row in cursor:
                print(row)
        elif self.gender == '남자' and self.old == '40대' and self.skin == '건성':
            sql22 = "select name, price, company from cosmetic_product where gender like '%남자%' and age like '%40대%' and type like '%건성%'"
            cursor.execute(sql22)
            for row in cursor:
                print(row)
        elif self.gender == '남자' and self.old == '40대' and self.skin == '지성':
            sql23 = "select name, price, company from cosmetic_product where gender like '%남자%' and age like '%40대%' and type like '%지성%'"
            cursor.execute(sql23)
            for row in cursor:
                print(row)
        elif self.gender == '남자' and self.old == '40대' and self.skin == '민감성':
            sql24 = "select name, price, company from cosmetic_product where gender like '%남자%' and age like '%40대%' and type like '%민감성%'"
            cursor.execute(sql24)
            for row in cursor:
                print(row)
        else:
            print("죄송합니다. 상품의 자료를 구축중입니다. 다음에 시도해주세요:(")



    def skin_typeall(self):  # 타입별 아이템 보기 함수
        while True:
            e = input("🟢 피부타입을 입력해주세요 1.건성  2.지성  3.민감성 ▶ ")
            if e == '1':

                sql25 = "select name, price, company from cosmetic_product where type like '%건성%'"
                cursor.execute(sql25)
                for row in cursor:
                    print(row)
                break
            elif e == '2':

                sql26 = "select name, price, company from cosmetic_product where type like '%지성%'"
                cursor.execute(sql26)
                for row in cursor:
                    print(row)
                break
            elif e == '3':

                sql27 = "select name, price, company from cosmetic_product where type like '%민감성%'"
                cursor.execute(sql27)
                for row in cursor:
                    print(row)
                break
            else:
                print("다시 선택해주세요.")

    def old_all(self): # 나이별 아이템 보기 함수
        print("➖" * 10, '나이별 화장품 전체보기', "➖" * 11, '\n')
        while True:
            a = input('🟡 나이대를 입력해주세요 1.10대  2.20대  3.30대  4.40대+ ▶  ')
            if a == '1':
                sql30 = "select name, price, company from cosmetic_product where age like '%10대%'"
                cursor.execute(sql30)
                for row in cursor:
                    print(row)
                break
            elif a == '2':
                sql31 = "select name, price, company from cosmetic_product where age like '%20대%'"
                cursor.execute(sql31)
                for row in cursor:
                    print(row)
                break
            elif a == '3':
                sql32 = "select name, price, company from cosmetic_product where age like '%30대%'"
                cursor.execute(sql32)
                for row in cursor:
                    print(row)
                break
            elif a == '4':
                sql33 = "select name, price, company from cosmetic_product where age like '%40대%'"
                cursor.execute(sql33)
                for row in cursor:
                    print(row)
                break

            else:
                print('다시 입력해주세요')

    def cosmetic_all(self): # 전체 화장품 리스트 출력 함수
        print("➖" * 10, '🖤 모든 화장품 전체보기 🖤', "➖" * 10, '\n')
        sql34 = "select name, price, company from cosmetic_product"
        cursor.execute(sql34)
        for row in cursor:
            print(row)

            
    def myresult(self):  # 이전에 조회한 결과 보기 함수
        if self.skin == '':
            print("이전 검사 결과가 없습니다. 메뉴로 돌아갑니다.")
        else:
            print(self.name + '님은 {}, {}, {}를 선택하셨습니다.'.format(self.gender, self.old, self.skin))
            while True:
                a = input('이전 내 결과를 기반으로 추천 서비스를 받으시겠습니까? [1] Y [2] N')
                if a == '1':
                    self.result()
                    break
                elif a == '2':
                    break
                else:
                    print('다시 입력해 주세요')

# %%
a = Cosmetic()
a.main_menu()
# Out:
#  ➖➖➖➖➖➖➖➖➖ S K I N C A R E  S E R V I C E ➖➖➖➖➖➖➖➖➖
# 1. 스킨케어 추천 서비스
# 2. 연령별 화장품 리스트 보기
# 3. 피부타입별 화장품 리스트 보기
# 4. 모든 화장품 리스트 보기
# 5. 이전 결과 리스트 보기
# 6. 로그인, 회원가입 메뉴
# 7. 종료
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖
#
# 			      🔹🔷🔹 접속 정보 🔹🔷🔹
# 아이디:   비밀번호:   이름:   전화번호: 입니다.
#
# 번호를 입력해 주세요 ▶ 6
#
#  ➖➖➖➖➖➖➖➖➖➖➖➖➖ J O I N ➖➖➖➖➖➖➖➖➖➖➖➖➖
# 1. 로그인
# 2. 회원가입
# 3. 메인 메뉴
# 4. 프로그램 종료
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖
#
# 			      🔹🔷🔹 접속 정보 🔹🔷🔹
# 아이디:   비밀번호:   이름:   전화번호: 입니다.
#
# 번호를 선택해 주세요 ▶ 2
# 회원가입합니다
# 아이디를 입력해 주세요 ▶ suin
# 규격에 맞지않습니다.
# 영어소문자와 숫자로 작성해주십시오.
# 아이디를 입력해 주세요 ▶ suin2638
# 올바른 형식입니다.
# 비밀번호를 입력해 주세요 ▶ 1234
# 1234 의 길이가 적당하지 않습니다.
# 비밀번호를 입력해 주세요 ▶ 123456
# 123456 대문자 또는 소문자가 모두 필요합니다.
# 비밀번호를 입력해 주세요 ▶ qwe123
# qwe123 대문자 또는 소문자가 모두 필요합니다.
# 비밀번호를 입력해 주세요 ▶ qwe123
# qwe123 대문자 또는 소문자가 모두 필요합니다.
# 비밀번호를 입력해 주세요 ▶ Qwe123
# Qwe123 올바른 형식의 비밀번호 입니다.
# 다시한번 입력해 주세요 ▶ Qwe123
# 이름 ▶ 손수인
# 올바른 형식입니다.
# 전화번호 ▶  01012345678
# 000-0000-0000 규격으로 입력해주세요.
# 다시 입력해주세요.
# 전화번호 ▶  010-1234-5678
# 000-0000-0000 규격으로 입력해주세요.
# 회원등록이 완료되었습니다.
#
#  귀하의 가입정보는
#  아이디 : suin2638
#  비밀번호 : Qwe123
#  이름 :손수인
#  전화번호 : 010-1234-5678입니다.
#
#  ➖➖➖➖➖➖➖➖➖➖➖➖➖ J O I N ➖➖➖➖➖➖➖➖➖➖➖➖➖
# 1. 로그아웃
# 2. 회원가입
# 3. 메인 메뉴
# 4. 프로그램 종료
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖
#
# 			      🔹🔷🔹 접속 정보 🔹🔷🔹
# 아이디: suin2638  비밀번호: Qwe123  이름: 손수인  전화번호: 010-1234-5678입니다.
#
# 번호를 선택해 주세요 ▶ 3
# 메인 메뉴로 이동합니다
#
#  ➖➖➖➖➖➖➖➖➖ S K I N C A R E  S E R V I C E ➖➖➖➖➖➖➖➖➖
# 1. 스킨케어 추천 서비스
# 2. 연령별 화장품 리스트 보기
# 3. 피부타입별 화장품 리스트 보기
# 4. 모든 화장품 리스트 보기
# 5. 이전 결과 리스트 보기
# 6. 로그아웃
# 7. 종료
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖
#
# 			      🔹🔷🔹 접속 정보 🔹🔷🔹
# 아이디: suin2638  비밀번호: Qwe123  이름: 손수인  전화번호: 010-1234-5678입니다.
#
# 번호를 입력해 주세요 ▶ 1
# ➖➖➖➖➖➖➖➖➖➖➖ 스킨케어 추천 서비스 ➖➖➖➖➖➖➖➖➖➖➖
#
# 🟠 성별을 입력해주세요 1.여자  2.남자 ▶ 1
# 🟡 나이대를 입력해주세요 1.10대  2.20대  3.30대  4.40대+ ▶  2
# 🟢 피부타입을 입력해주세요 1.건성  2.지성  3.민감성 ▶ 3
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖
#
#  손수인은 여자, 20대, 민감성를 선택하셨습니다.
# 결과를 보러 가시겠습니까? 1. Yes  2. No ▶ 1
#
#  ➖➖➖➖➖➖➖➖➖➖➖➖ 💌 결과 💌 ➖➖➖➖➖➖➖➖➖➖➖➖
#
# ('캐모마일 약산성 로션', 24000, '비플레인')
# ('피토 아쿠아 크림', 49000, '비욘드')
# ('녹두 밸런싱 토너', 42000, '비플레인')
#
#  ➖➖➖➖➖➖➖➖➖ S K I N C A R E  S E R V I C E ➖➖➖➖➖➖➖➖➖
# 1. 스킨케어 추천 서비스
# 2. 연령별 화장품 리스트 보기
# 3. 피부타입별 화장품 리스트 보기
# 4. 모든 화장품 리스트 보기
# 5. 이전 결과 리스트 보기
# 6. 로그아웃
# 7. 종료
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖
#
# 			      🔹🔷🔹 접속 정보 🔹🔷🔹
# 아이디: suin2638  비밀번호: Qwe123  이름: 손수인  전화번호: 010-1234-5678입니다.
#
# 번호를 입력해 주세요 ▶ 2
# ➖➖➖➖➖➖➖➖➖➖ 나이별 화장품 전체보기 ➖➖➖➖➖➖➖➖➖➖➖
#
# 🟡 나이대를 입력해주세요 1.10대  2.20대  3.30대  4.40대+ ▶  2
# ('다이브인 저분자 히알루론산 세럼', 22000, '토리든')
# ('녹두 밸런싱 토너', 18000, '비플레인')
# ('아쿠아 오아시스 토너', 25000, '에스네이처')
# ('비피다 바이옴 앰플 토너', 15000, '마녀공장')
# ('세라마이드 아토 로션', 32900, '일리윤')
# ('캐모마일 약산성 로션', 24000, '비플레인')
# ('울트라 페이션 모이스처라이징 로션', 9900, '시드물')
# ('레드 블레미쉬 멀티 플루이드', 95000, '닥터지')
# ('인텐시브 리파이닝 에멀젼', 33000, '라보드레')
# ('버치 아토 모이스처 로션', 40000, '오울루')
# ('데일리 레스큐 워터 로션', 55000, '랩시리즈')
# ('레드 블레미쉬 포 맨 올인원 플루이드', 29000, '닥터지')
# ('맨 올데이처첵트 올인원', 38000, '아이오페')
# ('시카 알로에 여드름 카밍 올인원 로션', 31000, '플리프')
# ('포 맨 퍼펙트 올인원', 27000, '아크네스')
# ('옴므 에센스 인 스킨', 46000, '헤라')
# ('아쿠아파워 토너', 58000, '바오템옴므')
# ('네버 오일리 올인원', 32000, '브로앤팁스')
# ('옴므 랩 올인원 플루이드', 29000, '차앤박화장품')
# ('엔젤아쿠아 포맨 올인원 에센스', 25000, '비욘드')
# ('히아루론산 수딩젤', 18000, '싸이닉')
# ('피토 아쿠아 크림', 49000, '비욘드')
# ('히알루로닉 아쿠아 젤', 18000, '비플레인')
# ('어성초 데일리 카밍젤', 13000, '다자연')
# ('시카플라스트 젤 B5', 25000, '라로슈포제')
# ('센텔라에센셜 ', 28600, '시드물')
# ('제주 왕벚꽃 젤리 크림', 20000, '이니스프리')
# ('화이트 트러플 비건 퍼스트 스프레이 세럼', 25000, '달바 ')
# ('어성초 추출물', 11000, '원씽')
# ('올리고 히알루론산 5000토너', 55000, '더랩바이블랑두')
# ('울트라 페이셜 모이스처라이징 로션', 9900, '시드물')
# ('레드 블레미쉬 멀티 플루이드', 95000, '닥터지')
# ('시카풀 카밍젤', 16000, '비플레인')
# ('티트리바이옴 블레미쉬 시카 토너', 20000, '메디힐')
# ('마다가스카르 센텔라 앰플', 22000, '스킨1004')
# ('녹두 밸런싱 토너', 42000, '비플레인')
#
#  ➖➖➖➖➖➖➖➖➖ S K I N C A R E  S E R V I C E ➖➖➖➖➖➖➖➖➖
# 1. 스킨케어 추천 서비스
# 2. 연령별 화장품 리스트 보기
# 3. 피부타입별 화장품 리스트 보기
# 4. 모든 화장품 리스트 보기
# 5. 이전 결과 리스트 보기
# 6. 로그아웃
# 7. 종료
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖
#
# 			      🔹🔷🔹 접속 정보 🔹🔷🔹
# 아이디: suin2638  비밀번호: Qwe123  이름: 손수인  전화번호: 010-1234-5678입니다.
#
# 번호를 입력해 주세요 ▶ 3
# 🟢 피부타입을 입력해주세요 1.건성  2.지성  3.민감성 ▶ 3
# ('캐모마일 약산성 로션', 24000, '비플레인')
# ('수딩 알로에 베라 젤', 33000, '아로마티카')
# ('레드 블레미쉬 포 맨 올인원 플루이드', 29000, '닥터지')
# ('피토 아쿠아 크림', 49000, '비욘드')
# ('녹두 밸런싱 토너', 42000, '비플레인')
#
#  ➖➖➖➖➖➖➖➖➖ S K I N C A R E  S E R V I C E ➖➖➖➖➖➖➖➖➖
# 1. 스킨케어 추천 서비스
# 2. 연령별 화장품 리스트 보기
# 3. 피부타입별 화장품 리스트 보기
# 4. 모든 화장품 리스트 보기
# 5. 이전 결과 리스트 보기
# 6. 로그아웃
# 7. 종료
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖
#
# 			      🔹🔷🔹 접속 정보 🔹🔷🔹
# 아이디: suin2638  비밀번호: Qwe123  이름: 손수인  전화번호: 010-1234-5678입니다.
#
# 번호를 입력해 주세요 ▶ 4
# ➖➖➖➖➖➖➖➖➖➖ 🖤 모든 화장품 전체보기 🖤 ➖➖➖➖➖➖➖➖➖➖
#
# ('1025 독도 토너', 15000, '라운드랩')
# ('레드 블레미쉬 클리어 수딩크림', 36000, '닥터지')
# ('다이브인 저분자 히알루론산 세럼', 22000, '토리든')
# ('어성초 77% 수딩 토너', 45000, '아누아')
# ('더 심플 데일리 로션', 28000, '싸이닉')
# ('비자 시카 잠', 23000, '이니스프리')
# ('티트리 시카 수딩 크림', 16000, '브링그린')
# ('원더 세라마이드 모찌 토너', 15000, '토니모리')
# ('녹두 밸런싱 토너', 18000, '비플레인')
# ('아쿠아 오아시스 토너', 25000, '에스네이처')
# ('비피다 바이옴 앰플 토너', 15000, '마녀공장')
# ('세라마이드 아토 로션', 32900, '일리윤')
# ('캐모마일 약산성 로션', 24000, '비플레인')
# ('울트라 페이션 모이스처라이징 로션', 9900, '시드물')
# ('레드 블레미쉬 멀티 플루이드', 95000, '닥터지')
# ('인텐시브 리파이닝 에멀젼', 33000, '라보드레')
# ('버치 아토 모이스처 로션', 40000, '오울루')
# ('아쿠아 스쿠알란 수분크림', 35000, '에스네이처')
# ('수딩 알로에 베라 젤', 33000, '아로마티카')
# ('자작나무 수분 크림', 32000, '라운드랩')
# ('아토베리어 365크림', 31000, '에스트라')
# ('아쿠아 콜라겐 펩타이드 젤에센스', 44500, '에스네이처')
# ('아토로션 블루라벨', 36000, '편강율')
# ('콜라겐 폭탄 대용량 앰플', 28000, '배드스킨')
# ('어성초 케어 세럼', 47000, '다자연')
# ('DMT 페이셜 크림', 43900, '피지오겔')
# ('순수 갈락토미세스 앰플97%', 18000, '셀비엔')
# ('MLE로션', 25000, '아토팜')
# ('데일리 레스큐 워터 로션', 55000, '랩시리즈')
# ('레드 블레미쉬 포 맨 올인원 플루이드', 29000, '닥터지')
# ('맨 올데이처첵트 올인원', 38000, '아이오페')
# ('시카 알로에 여드름 카밍 올인원 로션', 31000, '플리프')
# ('포 맨 퍼펙트 올인원', 27000, '아크네스')
# ('옴므 에센스 인 스킨', 46000, '헤라')
# ('아쿠아파워 토너', 58000, '바오템옴므')
# ('네버 오일리 올인원', 32000, '브로앤팁스')
# ('옴므 랩 올인원 플루이드', 29000, '차앤박화장품')
# ('엔젤아쿠아 포맨 올인원 에센스', 25000, '비욘드')
# ('히아루론산 수딩젤', 18000, '싸이닉')
# ('피토 아쿠아 크림', 49000, '비욘드')
# ('히알루로닉 아쿠아 젤', 18000, '비플레인')
# ('어성초 데일리 카밍젤', 13000, '다자연')
# ('시카플라스트 젤 B5', 25000, '라로슈포제')
# ('센텔라에센셜 ', 28600, '시드물')
# ('제주 왕벚꽃 젤리 크림', 20000, '이니스프리')
# ('화이트 트러플 비건 퍼스트 스프레이 세럼', 25000, '달바 ')
# ('어성초 추출물', 11000, '원씽')
# ('올리고 히알루론산 5000토너', 55000, '더랩바이블랑두')
# ('울트라 페이셜 모이스처라이징 로션', 9900, '시드물')
# ('레드 블레미쉬 멀티 플루이드', 95000, '닥터지')
# ('시카풀 카밍젤', 16000, '비플레인')
# ('티트리바이옴 블레미쉬 시카 토너', 20000, '메디힐')
# ('마다가스카르 센텔라 앰플', 22000, '스킨1004')
# ('녹두 밸런싱 토너', 42000, '비플레인')
#
#  ➖➖➖➖➖➖➖➖➖ S K I N C A R E  S E R V I C E ➖➖➖➖➖➖➖➖➖
# 1. 스킨케어 추천 서비스
# 2. 연령별 화장품 리스트 보기
# 3. 피부타입별 화장품 리스트 보기
# 4. 모든 화장품 리스트 보기
# 5. 이전 결과 리스트 보기
# 6. 로그아웃
# 7. 종료
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖
#
# 			      🔹🔷🔹 접속 정보 🔹🔷🔹
# 아이디: suin2638  비밀번호: Qwe123  이름: 손수인  전화번호: 010-1234-5678입니다.
#
# 번호를 입력해 주세요 ▶ 5
# 손수인님은 여자, 20대, 민감성를 선택하셨습니다.
# 이전 내 결과를 기반으로 추천 서비스를 받으시겠습니까? [1] Y [2] N1
#
#  ➖➖➖➖➖➖➖➖➖➖➖➖ 💌 결과 💌 ➖➖➖➖➖➖➖➖➖➖➖➖
#
# ('캐모마일 약산성 로션', 24000, '비플레인')
# ('피토 아쿠아 크림', 49000, '비욘드')
# ('녹두 밸런싱 토너', 42000, '비플레인')
#
#  ➖➖➖➖➖➖➖➖➖ S K I N C A R E  S E R V I C E ➖➖➖➖➖➖➖➖➖
# 1. 스킨케어 추천 서비스
# 2. 연령별 화장품 리스트 보기
# 3. 피부타입별 화장품 리스트 보기
# 4. 모든 화장품 리스트 보기
# 5. 이전 결과 리스트 보기
# 6. 로그아웃
# 7. 종료
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖
#
# 			      🔹🔷🔹 접속 정보 🔹🔷🔹
# 아이디: suin2638  비밀번호: Qwe123  이름: 손수인  전화번호: 010-1234-5678입니다.
#
# 번호를 입력해 주세요 ▶ 7
# 프로그램을 종료합니다.
